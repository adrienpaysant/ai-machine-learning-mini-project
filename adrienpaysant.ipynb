# %%
#Load the data
from src.main import loadData
import matplotlib.pyplot as plt
X,y = loadData()

# %%
#Split data
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=0, shuffle=True)

# %%
from sklearn.naive_bayes import GaussianNB
#train model
clf = GaussianNB()
model = clf.fit(X_train, y_train)

# %%
#perfs eval
from sklearn import metrics
import matplotlib.pyplot as plt  
from sklearn.metrics import plot_confusion_matrix

y_pred = model.predict(X_test)

accuracy = metrics.accuracy_score(y_test, y_pred)
scoreMicro = metrics.f1_score(y_test, y_pred, average="micro")
scoreMacro = metrics.f1_score(y_test, y_pred, average="macro")

print(f"Accuracy : {100*accuracy}%\nMacro :\n\tscore micro (f1): {scoreMicro}\n\tscore macro (f1) : {scoreMacro}")

plot_confusion_matrix(model, X_test, y_test)
# Out:
# Accuracy : 89.65253913707521%
# Macro :
# 	score micro (f1): 0.8965253913707522
# 	score macro (f1) : 0.8934237833567439
